# %% [markdown]
# ### Working with delta lakes and spark via Databricks

# %%
from delta import *
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("MyApp") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=52368859589716#setting/sparkui/0128-165643-erqkptyh/driver-6719764943701249625">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# creates delta table
data = spark.range(0, 10)
data.write.format("delta").save("/tmp/delta-table")

# %%
del data

# %%
df = spark.read.format("delta").load("/tmp/delta-table")
df.show()
# Out:
# +---+
# | id|
# +---+
# |  3|
# |  4|
# |  8|
# |  9|
# |  0|
# |  1|
# |  2|
# |  5|
# |  6|
# |  7|
# +---+

# %%
# example of updating data
data = spark.range(10, 20)
data.write.format("delta").mode("overwrite").save("/tmp/delta-table")

# %%
df = spark.read.format("delta").load("/tmp/delta-table")
df.show()
# Out:
# +---+
# | id|
# +---+
# | 13|
# | 14|
# | 18|
# | 19|
# | 11|
# | 12|
# | 15|
# | 16|
# | 17|
# | 10|
# +---+

# %%
# time travel to read old versions of data
df0 = spark.read.format("delta").option("versionAsOf", 0).load("/tmp/delta-table")
df0.show()
# Out:
# +---+
# | id|
# +---+
# |  3|
# |  4|
# |  8|
# |  9|
# |  0|
# |  1|
# |  2|
# |  5|
# |  6|
# |  7|
# +---+

# %%
# updating odd values by adding 100

from delta.tables import *
from pyspark.sql.functions import *

# set the path
deltaTable = DeltaTable.forPath(spark, "/tmp/delta-table")

# update logic for the delta
deltaTable.update(
  condition = expr("id % 2 == 1"),
  set = { "id": expr("id + 100") })

deltaTable.toDF().show()
# Out:
# +---+
# | id|
# +---+
# |113|
# | 14|
# | 18|
# |119|
# | 12|
# | 16|
# |111|
# |115|
# |117|
# | 10|
# +---+

# %%
from delta.tables import *

deltaTable = DeltaTable.forPath(spark, "/tmp/delta-table")

fullHistoryDF = deltaTable.history()    # get the full history of the table

lastOperationDF = deltaTable.history(1) # get the last operation

# %%
fullHistoryDF.show()
# Out:
# +-------+-------------------+----------------+-------------------+---------+--------------------+----+------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+
# |version|          timestamp|          userId|           userName|operation| operationParameters| job|          notebook|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|
# +-------+-------------------+----------------+-------------------+---------+--------------------+----+------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+
# |      2|2022-01-28 18:09:12|6584847049774054|dbw2tn@virginia.edu|   UPDATE|{predicate -> ((i...|null|{3205054796946383}|0128-165643-erqkptyh|          1|WriteSerializable|        false|{numRemovedFiles ...|        null|
# |      1|2022-01-28 18:08:55|6584847049774054|dbw2tn@virginia.edu|    WRITE|{mode -> Overwrit...|null|{3205054796946383}|0128-165643-erqkptyh|          0|WriteSerializable|        false|{numFiles -> 8, n...|        null|
# |      0|2022-01-28 18:08:42|6584847049774054|dbw2tn@virginia.edu|    WRITE|{mode -> ErrorIfE...|null|{3205054796946383}|0128-165643-erqkptyh|       null|WriteSerializable|         true|{numFiles -> 8, n...|        null|
# +-------+-------------------+----------------+-------------------+---------+--------------------+----+------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+

# %%
fullHistoryDF.select('version','operation','operationMetrics').show(truncate=False)
# Out:
# +-------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |version|operation|operationMetrics                                                                                                                                                                 |
# +-------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2      |UPDATE   |{numRemovedFiles -> 5, numCopiedRows -> 2, numAddedChangeFiles -> 0, executionTimeMs -> 6432, scanTimeMs -> 3737, numAddedFiles -> 5, numUpdatedRows -> 5, rewriteTimeMs -> 2694}|
# |1      |WRITE    |{numFiles -> 8, numOutputBytes -> 4415, numOutputRows -> 10}                                                                                                                     |
# |0      |WRITE    |{numFiles -> 8, numOutputBytes -> 4416, numOutputRows -> 10}                                                                                                                     |
# +-------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# %sql

DESCRIBE DETAIL "/tmp/delta-table"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>6b6a802a-cca8-480f-a6e6-f5ddee06eb56</td><td>null</td><td>null</td><td>dbfs:/tmp/delta-table</td><td>2022-01-28T18:08:37.012+0000</td><td>2022-01-28T18:09:12.000+0000</td><td>List()</td><td>8</td><td>4415</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
dbutils.fs.rm('/tmp/delta-table',recurse=True)
# Out:
# Out[30]: True
